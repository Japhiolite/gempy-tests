# %%
import sys
sys.path.insert(0,'../../gempy/')

import gempy as gp
import numpy as np

import theano  # type: ignore

theano.config.gcc.cxxflags = "-Wno-c++11-narrowing"
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
print(gp.__file__)
# Out:
# C:\Users\Simon\Documents\git\gempy-tests\notebooks\../../gempy\gempy\__init__.py

# %%
# Import data
# Create a model instance
np.random.seed(1)
glob_model = gp.create_model('global_model')

# Initialize the model, set dimension and load interface and orientation data
gp.init_data(glob_model, [0, 100., 0, 50., 0, 100.], [50, 50, 50],
            path_i = '../data/hierarchical_modeling/hierarchical_model_interfaces_fault.csv',
            path_o = '../data/hierarchical_modeling/hierarchical_model_orientations_fault.csv');

glob_model.set_topography(source='random', d_z=(85,100), fd=1.2)
# Out:
# Active grids: ['regular']
# Active grids: ['regular' 'topography']
# Grid Object. Values:
# array([[  1.        ,   0.5       ,   1.        ],
#        [  1.        ,   0.5       ,   3.        ],
#        [  1.        ,   0.5       ,   5.        ],
#        ...,
#        [100.        ,  47.95918367,  97.08673384],
#        [100.        ,  48.97959184,  96.6483559 ],
#        [100.        ,  50.        ,  96.45189706]])

# %%
# set interpolator
gp.set_interpolator(glob_model, theano_optimizer='fast_compile', verbose=[])

# Compute the model
sol_glob = gp.compute_model(glob_model)
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                       values
# range                 150.0
# $C_o$            535.714286
# drift equations      [3, 3]

# %%
gp.plot_2d(glob_model, cell_number=25, show_topography=True)
# Out:
# C:\Users\Simon\Documents\git\gempy-tests\notebooks\../../gempy\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gp.plot_2d(glob_model, section_names='topography', show_topography=True)

# %% [markdown]
# # using `reshape(order='F')`

# %%
gp.plot_2d(glob_model, cell_number=25, show_topography=True)
# Out:
# C:\Users\Simon\Documents\git\gempy-tests\notebooks\../../gempy\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gp.plot_2d(glob_model, section_names='topography', show_topography=True)
