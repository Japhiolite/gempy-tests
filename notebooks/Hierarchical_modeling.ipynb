# %% [markdown]
# # Hierarchical modeling
#
# From [Issue #271](https://github.com/cgre-aachen/gempy/issues/271) a description by flohorovicic:
# "We often have several regions in a model domain with different geological elements. In this case, a global interpolation will very likely cause problems.
#
# Simple example: faults, different models on both sides (although this is an aspect that can be handled with gempy - serves here as purpose of example). A typical procedure would be to:
#
# 1. Define a model to separate the entire modeling domain into different regions
# 2. Interpolate a model in each of these regions separately (note: the model will be defined in the entire domain, but only "active" in a specific region)
# 3. Combine a final model using the high-hierarchy "domain map" and the corresponding low-hierarchy submodels."
#
# <img src="https://user-images.githubusercontent.com/1070677/75426800-aa1f1280-5945-11ea-9062-d33a7be2da21.png" width=800>

# %%
# import libraries
# These two lines are necessary only if GemPy is not installed
import sys, os
sys.path.append("../../gempy/")

# Importing GemPy
import gempy as gp

# Embedding matplotlib figures in the notebooks
# %matplotlib inline

# Importing auxiliary libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## "High hierarchy model"

# %%
# Import data
# Create a model instance
glob_model = gp.create_model('global_model')

# Initialize the model, set dimension and load interface and orientation data
gp.init_data(glob_model, [0, 100., 0, 50., 0, 100.], [50, 50, 50],
            path_i = '../data/hierarchical_modeling/hierarchical_model_interfaces_fault.csv',
            path_o = '../data/hierarchical_modeling/hierarchical_model_orientations_fault.csv');

# set interpolator
gp.set_interpolator(glob_model, theano_optimizer='fast_compile', verbose=[])

# Compute the model
sol_glob = gp.compute_model(glob_model)
# Out:
# Active grids: ['regular']
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                    values
# range                150
# $C_o$            535.714
# drift equations   [3, 3]

# %%
gp.plot_2d(glob_model, cell_number=25)
# Out:
# ../../gempy\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %% [markdown]
# ## Low-hierarchy model (left)

# %%
# Import data
# Create a model instance
left_model = gp.create_model('left_model')

# Initialize the model, set dimension and load interface and orientation data
gp.init_data(left_model, [0, 100., 0, 50., 0, 100.], [50, 50, 50],
            path_i = '../data/hierarchical_modeling/hierarchical_model_interfaces_left.csv',
            path_o = '../data/hierarchical_modeling/hierarchical_model_orientations_left.csv')

# set interpolator
gp.set_interpolator(left_model, theano_optimizer='fast_compile', verbose=[])

# Compute the model
sol_left = gp.compute_model(left_model);
# Out:
# Active grids: ['regular']
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                    values
# range                150
# $C_o$            535.714
# drift equations   [3, 3]

# %%
gp.plot_2d(left_model, cell_number=25);
# Out:
# ../../gempy\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %% [markdown]
# ## Low-hierarchy model (right)

# %%
# Import data
# Create a model instance
right_model = gp.create_model('right_model')

# Initialize the model, set dimension and load interface and orientation data
gp.init_data(right_model, [0, 100., 0, 50., 0, 100.], [50, 50, 50],
            path_i = '../data/hierarchical_modeling/hierarchical_model_interfaces_right.csv',
            path_o = '../data/hierarchical_modeling/hierarchical_model_orientations_right.csv')

# set interpolator
gp.set_interpolator(right_model, theano_optimizer='fast_compile', verbose=[])

# Compute the model
sol_glob = gp.compute_model(right_model);
# Out:
# Active grids: ['regular']
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                    values
# range                150
# $C_o$            535.714
# drift equations   [3, 3]

# %%
gp.plot_2d(right_model, cell_number=25)
# Out:
# ../../gempy\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %% [markdown]
# ## Combined model
#
# The high-hierarchy model divides the model space in two parts essentially. Each of the low-hierarchy models is then modeled in the respective regions. Combining the domains then yields the total model which looks similar to the one in the right figure at the top of this notebook.
# For showing how the final, combined model would look like, we model the high-hierarchy model in gempy as a fault.
# *Note:* this is not the same as hierarchical modeling, but the result should look the same.

# %%
# Import data
# Create a model instance
comb_model = gp.create_model('combined_model')

# Initialize the model, set dimension and load interface and orientation data
gp.init_data(comb_model, [0, 100., 0, 50., 0, 100.], [50, 50, 50],
            path_i = '../data/hierarchical_modeling/hierarchical_model_interfaces.csv',
            path_o = '../data/hierarchical_modeling/hierarchical_model_orientations.csv')

# set interpolator
gp.set_interpolator(comb_model, theano_optimizer='fast_compile', verbose=[])
# Out:
# Active grids: ['regular']
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                    values
# range                150
# $C_o$            535.714
# drift equations   [3, 3]

# %%
# assign surfaces to series
gp.map_series_to_surfaces(comb_model,
                         {"Fault_series": 'fault',
                         "Lith_series": ('l3_left', 'l2_left', 'l1_left')},
                         remove_unused_series=True)
comb_model.set_is_fault('Fault_series', change_color=False)
# Out:
#               order_series BottomRelation  isActive  isFault  isFinite
# Fault_series             1          Fault      True     True     False
# Lith_series              2        Erosion      True    False     False
# Basement                 3        Erosion     False    False     False

# %%
# Compute the model
sol_comb = gp.compute_model(comb_model)

# %%
gp.plot_2d(comb_model, cell_number=25)
# Out:
# ../../gempy\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
p3d = gp.plot_3d(comb_model, plotter_type='background')

# %%
p3d.surface_poly[:].save("comb_model.vtk")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-9593325b9da1> in <module>
# ----> 1 p3d.surface_poly[:].save("comb_model.vtk")
#
# TypeError: unhashable type: 'slice'

# %%
def save_the_meshes(model):
    p3d = gp.plot_3d(model, plotter_type='background')
    names = p3d.surface_poly.keys()
    
    for i in names:
        p3d.surface_poly[i].save(f"../models/hierarchical_models/glob_model/{i}.vtk")

# %%
save_the_meshes(glob_model)

# %%
[p3d.surface_poly[i].save(f"{i}.vtk" for i in p3d.surface_poly.keys())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-db712a89cbd8> in <module>
# ----> 1 [p3d.surface_poly[i].save(f"{i}.vtk" for i in p3d.surface_poly.keys())]
#
# NameError: name 'i' is not defined
